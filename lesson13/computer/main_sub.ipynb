# %%
import os
os.path.abspath(__name__) #取得絕對路徑
root_dir = os.getcwd()
data_dir = os.path.join(root_dir, 'data')
data_dir

if os.path.isdir(data_dir):
    print('directory exists.')
else:
    print('directory not exists.')
# Out:
# directory exists.

# %%
import os
os.path.abspath(__name__) #取得絕對路徑
root_dir = os.getcwd()
data_dir = os.path.join(root_dir, 'data')
data_dir

if not os.path.isdir(data_dir):
    os.mkdir('data')

# %%
from datetime import datetime
today = datetime.today()
filename = today.strftime("%y-%m-%d") + ".csv"

#get file arbspath
full_path = os.path.join(data_dir, filename)
full_path
# Out:
# 'c:\\Users\\User\\Documents\\GitHub\\20240831_pico_lab\\lesson13\\computer\\data\\24-10-12.csv'

# %%
if not os.path.exists(full_path):
    #如沒有檔案則建立檔案
    print('檔案不存在')
    with open(full_path, mode='w', encoding='utf-8', newline='') as file:
        file.write('時間,設備,值\n')
# Out:
# 檔案不存在

# %%
import csv
now = datetime.now()
nowstr = today.strftime('%y-%m-%d %H:%M:%S')
header = [nowstr, "SA-12/LED_LEVEL", 7] #組成List

with open(full_path, mode='a', encoding='utf-8', newline='') as file:
    writer = csv.writer(file)
    writer.writerow(header)
