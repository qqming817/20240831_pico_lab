# %%
import random
import time

for i in range(100):
    print(random.randint(1, 10))
    time.sleep(1)

# %%
import requests
r = requests.get('https://api.github.com/events')
type(r)
# Out:
# requests.models.Response

# %%
r.text
# Out:
# '[{"id":"41926819288","type":"PushEvent","actor":{"id":878058,"login":"ParkMinKyu","display_login":"ParkMinKyu","gravatar_id":"","url":"https://api.github.com/users/ParkMinKyu","avatar_url":"https://avatars.githubusercontent.com/u/878058?"},"repo":{"id":362471221,"name":"ApartMoney/Apartmoney.github.io","url":"https://api.github.com/repos/ApartMoney/Apartmoney.github.io"},"payload":{"repository_id":362471221,"push_id":20235331295,"size":1,"distinct_size":1,"ref":"refs/heads/master","head":"3679e4278351fdd05aa70c19666238517c2c24fb","before":"f8a41a8e9281e9a86f9e29d23498f731ba0aefe3","commits":[{"sha":"3679e4278351fdd05aa70c19666238517c2c24fb","author":{"email":"niee@naver.com","name":"ParkMinkyu"},"message":"update news data","distinct":true,"url":"https://api.github.com/repos/ApartMoney/Apartmoney.github.io/commits/3679e4278351fdd05aa70c19666238517c2c24fb"}]},"public":true,"created_at":"2024-09-14T07:50:04Z","org":{"id":60907646,"login":"ApartMoney","gravatar_id":"","url":"https://ap
# ...
