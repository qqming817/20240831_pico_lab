# %%
import sqlite3
from sqlite3 import Error

try:
    conn = sqlite3.connect('pico.db')
except Exception as e:
    print (e)

# %%
sql = """
INSERT INTO chicken_accmodation (record_date, equipment, value) VALUES (
?,?,?)
"""

myCursor =  conn.cursor()
myCursor.execute(sql, ('24-10-12 16:17:38', 'SA-12/LED_LEVEL', 32.4))
conn.commit()
myCursor.close()
conn.close()
